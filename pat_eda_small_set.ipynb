# %%
import pandas as pd
import matplotlib.pyplot as plt
import itertools
import numpy as np
plt.style.use('ggplot')

# %%
df = pd.read_csv('data.csv', index_col='Unnamed: 0')

# %%
df.head(2)
# Out:
#                                            name       tempo  beats  \
# 0  Amilcare Ponchielli - Dance of the Hours.mp3  130.813953    394
# 1   Rossini - William Tell Overture - Final.mp3  160.714286    443
#
#    chroma_stft      rmse    spec_cent      spec_bw      rolloff       zcr  \
# 0     0.292340  0.042382  1637.235974  2228.712920  2925.815507  0.038808
# 1     0.388742  0.057814  1357.984086  1875.937831  2628.860882  0.028938
#
#        mfcc_1    ...         mfcc_3    mfcc_4    mfcc_5    mfcc_6    mfcc_7  \
# 0  164.360115    ...       4.918759  4.767190  3.798379 -2.531283 -0.907902
# 1  165.760189    ...      22.165190  5.195708  9.989042 -3.362946  3.713702
#
#      mfcc_8    mfcc_9   mfcc_10   mfcc_11      label
# 0 -2.287565  0.083561 -2.888623 -3.455121  Classical
# 1 -3.914152 -1.442259 -3.176913 -2.756510  Classical
#
# [2 rows x 21 columns]

# %%
elec = df[df.label=='Electronic']
metal = df[df.label=='Metal']
hip_hop = df[df.label=='Hip_Hop']
jazz = df[df.label=='Jazz']
classical = df[df.label=='Classical']
country = df[df.label=='Country']
plt.hist(elec.mfcc_1, alpha=0.5)
plt.hist(hip_hop.mfcc_1, alpha=0.5)
# Out:
# (array([ 3.,  9., 12., 23., 20., 22., 10.,  6.,  2.,  1.]),
#  array([-52.46130608, -44.79583663, -37.13036718, -29.46489773,
#         -21.79942828, -14.13395883,  -6.46848938,   1.19698007,
#           8.86244953,  16.52791898,  24.19338843]),
#  <a list of 10 Patch objects>)

# %%
col = 'chroma_stft'

for g1, g2 in itertools.combinations(df.label.unique(), 2):
    plt.figure(figsize=(6,3))
    plt.hist(df.loc[df.label == g1, col], alpha=0.5, label=g1)
    plt.hist(df.loc[df.label == g2, col], alpha=0.5, label=g2)
    plt.title(col)
    plt.legend()
    plt.show()
